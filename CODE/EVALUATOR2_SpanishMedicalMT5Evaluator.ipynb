# %%
import json
import pandas as pd
import os
import time
from datetime import datetime
import numpy as np
import re
from google.colab import drive
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

class SpanishMedicalMT5Evaluator:
    def __init__(self, questions_file: str, model_name: str = "google/mt5-large", max_consecutive_errors: int = 5):
        """
        Initialize evaluator with questions file and error threshold.
        model_name: HuggingFace model identifier
        max_consecutive_errors: stops evaluation if this many errors occur in a row
        """
        self.max_consecutive_errors = max_consecutive_errors
        self.model_name = model_name
        self.load_questions(questions_file)
        self.results = []

        # Initialize model and tokenizer
        print(f"Loading {model_name}...")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

        # Move model to GPU if available
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = self.model.to(self.device)
        print(f"Model loaded and moved to {self.device}")

    def load_questions(self, file_path: str):
        with open(file_path, 'r', encoding='utf-8') as f:
            self.questions = json.load(f)
            print(f"Loaded {len(self.questions)} questions")

    def format_prompt(self, question):
        """Format prompt for medical question answering in Spanish"""
        return f"""Instrucciones: Lee cuidadosamente esta pregunta médica y elige la respuesta correcta.
Responde únicamente con la letra correspondiente (A, B, C, o D).

Pregunta médica: {question['question']}

Opciones:
A) {question['option_a']}
B) {question['option_b']}
C) {question['option_c']}
D) {question['option_d']}

Basándote en tu conocimiento médico, selecciona la opción correcta (A/B/C/D):"""

    def extract_answer(self, raw_answer):
        """Extract the answer letter using multiple patterns"""
        patterns = [
            r"^\s*([ABCD])(\b|\.|$)",  # Just the letter
            r".*[^a-zA-Z]([ABCD])(\b|\.|$)",  # Letter at the end
            r"([ABCD])[^\w\s]*$",  # Letter followed by punctuation at end
            r".*\b([ABCD])\b.*",  # Letter as a word
            r".*([ABCD]).*"  # Any letter anywhere
        ]

        for pattern in patterns:
            match = re.search(pattern, raw_answer, re.IGNORECASE)
            if match:
                return match.group(1).upper()
        return None

    def get_model_response(self, prompt):
        """Get response from MT5 model"""
        # Tokenize input
        inputs = self.tokenizer(prompt, return_tensors="pt", max_length=1024, truncation=True)
        inputs = {k: v.to(self.device) for k, v in inputs.items()}

        # Generate response
        with torch.no_grad():
            outputs = self.model.generate(
                **inputs,
                max_length=8,  # Short since we only need a letter
                min_length=1,
                num_beams=4,
                temperature=0.3,  # Lower temperature for more focused responses
                no_repeat_ngram_size=2,
                early_stopping=True,
                do_sample=False  # Deterministic generation
            )

        # Decode response
        response = self.tokenizer.decode(outputs[0], skip_special_tokens=True)
        return response.strip()

    def evaluate_model(self, test_run: bool = False):
        """
        Evaluate questions using MT5 model.
        test_run: if True, only evaluates first 5 questions
        """
        consecutive_errors = 0
        questions_to_evaluate = self.questions[:5] if test_run else self.questions

        # For test run, we'll still abort on consecutive errors
        max_errors = self.max_consecutive_errors if test_run else float('inf')

        for i, question in enumerate(questions_to_evaluate):
            try:
                start_time = time.time()
                prompt = self.format_prompt(question)

                print("\nProcessing Question:")
                print(f"ID: {question['id']}")
                print(f"Prompt length: {len(prompt)} characters")

                # Get model response
                raw_answer = self.get_model_response(prompt)
                end_time = time.time()

                print(f"Raw response: {raw_answer}")

                # Try to extract the answer using multiple patterns
                model_answer = self.extract_answer(raw_answer)

                if not model_answer:
                    print(f"Warning: Could not extract answer from response: {raw_answer}")
                    model_answer = "invalid"

                result = {
                    'question_id': question['id'],
                    'model': self.model_name,
                    'question_input': question['question'],
                    'model_raw_output': raw_answer,
                    'answer': model_answer if model_answer in ['A', 'B', 'C', 'D'] else None,
                    'correct_answer': question['correct_answer'],
                    'correct': model_answer == question['correct_answer'] if model_answer in ['A', 'B', 'C', 'D'] else False,
                    'time': end_time - start_time,
                    'error': None if model_answer in ['A', 'B', 'C', 'D'] else f"Invalid format: {raw_answer}"
                }

                self.results.append(result)

                if model_answer in ['A', 'B', 'C', 'D']:
                    consecutive_errors = 0
                else:
                    consecutive_errors += 1

                print(f"\nEvaluation:")
                print(f"Question {i+1}/{len(questions_to_evaluate)}")
                print(f"Extracted answer: {model_answer}")
                print(f"Correct answer: {question['correct_answer']}")
                print(f"Time: {result['time']:.2f}s")
                print("-" * 40)

                # Add delay to respect rate limits
                time.sleep(1)

                if consecutive_errors >= max_errors and test_run:
                    print(f"\nAborting test run: {consecutive_errors} consecutive errors")
                    break

            except Exception as e:
                error_msg = str(e)
                print(f"Error on question {i+1}: {error_msg}")

                self.results.append({
                    'question_id': question['id'],
                    'model': self.model_name,
                    'question_input': question['question'],
                    'model_raw_output': None,
                    'answer': None,
                    'correct_answer': question['correct_answer'],
                    'correct': False,
                    'time': None,
                    'error': error_msg
                })

                consecutive_errors += 1
                if consecutive_errors >= max_errors and test_run:
                    print(f"\nAborting test run: {consecutive_errors} consecutive errors")
                    break

        return self.save_results()

    def save_results(self, output_dir: str = '/content/drive/MyDrive/TFM2/TFM-DATASETS/evaluations'):
        """Save results and return summary metrics."""
        os.makedirs(output_dir, exist_ok=True)
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

        # Convert to DataFrame
        df = pd.DataFrame(self.results)

        # Calculate metrics
        metrics = {
            'model': self.model_name,
            'total_questions': len(df),
            'completed': df['error'].isna().sum(),
            'errors': df['error'].notna().sum(),
            'correct': df['correct'].sum(),
            'accuracy': df['correct'].mean(),
            'avg_time': df['time'].mean(),
            'invalid_formats': len(df[df['answer'].isna()]),
            'valid_responses': len(df[df['answer'].notna()])
        }

        # Convert NumPy types to standard Python types for JSON serialization
        metrics = {k: v.item() if isinstance(v, (np.int64, np.int32)) else v for k, v in metrics.items()}

        # Save results
        model_short_name = "mt5_medical_spanish"
        base_path = f"{output_dir}/eval_{model_short_name}_{timestamp}"
        df.to_csv(f"{base_path}_results.csv", index=False)

        with open(f"{base_path}_summary.json", 'w') as f:
            json.dump(metrics, f, indent=2)

        # Print summary
        print("\nEvaluation Summary:")
        print(f"Model: {self.model_name}")
        print(f"Total Questions: {metrics['total_questions']}")
        print(f"Valid Responses: {metrics['valid_responses']}")
        print(f"Invalid Formats: {metrics['invalid_formats']}")
        print(f"Correct Answers: {metrics['correct']}")
        print(f"Accuracy (of valid): {metrics['accuracy']:.2%}")
        if metrics['avg_time']:
            print(f"Avg Time: {metrics['avg_time']:.2f}s")

        return metrics


def run_test_evaluation():
    """Run a test evaluation with just 5 questions."""
    questions_file = '/content/drive/MyDrive/TFM2/TFM-DATASETS/structured_questions.json'
    evaluator = SpanishMedicalMT5Evaluator(questions_file)
    return evaluator.evaluate_model(test_run=True)

def run_full_evaluation():
    """Run the full evaluation."""
    questions_file = '/content/drive/MyDrive/TFM2/TFM-DATASETS/structured_questions.json'
    evaluator = SpanishMedicalMT5Evaluator(questions_file)
    return evaluator.evaluate_model()

# First install required packages
# !pip install -q transformers torch

# Mount Google Drive
drive.mount('/content/drive')

# Run test evaluation
print("\nRunning test evaluation with 5 questions...")
test_metrics = run_test_evaluation()

# Ask user if they want to continue
if input("\nContinue with full evaluation? (y/n): ").lower() == 'y':
    print("\nRunning full evaluation...")
    full_metrics = run_full_evaluation()
# Out:
# Mounted at /content/drive
#
# Running test evaluation with 5 questions...
# Loaded 174 questions
# Loading google/mt5-large...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/376 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Model loaded and moved to cpu
#
# Processing Question:
# ID: 26
# Prompt length: 950 characters
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.3` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Raw response: <extra_id_0>ro sérico. <extra_id_1>
#
# Evaluation:
# Question 1/5
# Extracted answer: D
# Correct answer: B
# Time: 27.28s
# ----------------------------------------
#
# Processing Question:
# ID: 27
# Prompt length: 757 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 2/5
# Extracted answer: C
# Correct answer: C
# Time: 11.08s
# ----------------------------------------
#
# Processing Question:
# ID: 28
# Prompt length: 798 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 3/5
# Extracted answer: A
# Correct answer: A
# Time: 10.90s
# ----------------------------------------
#
# Processing Question:
# ID: 29
# Prompt length: 776 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 4/5
# Extracted answer: C
# Correct answer: B
# Time: 12.43s
# ----------------------------------------
#
# Processing Question:
# ID: 30
# Prompt length: 792 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 5/5
# Extracted answer: C
# Correct answer: C
# Time: 12.68s
# ----------------------------------------
#
# Evaluation Summary:
# Model: google/mt5-large
# Total Questions: 5
# Valid Responses: 5
# Invalid Formats: 0
# Correct Answers: 3
# Accuracy (of valid): 60.00%
# Avg Time: 14.87s
#
# Continue with full evaluation? (y/n): y
#
# Running full evaluation...
# Loaded 174 questions
# Loading google/mt5-large...
# Model loaded and moved to cpu
#
# Processing Question:
# ID: 26
# Prompt length: 950 characters
# Raw response: <extra_id_0>ro sérico. <extra_id_1>
#
# Evaluation:
# Question 1/174
# Extracted answer: D
# Correct answer: B
# Time: 17.10s
# ----------------------------------------
#
# Processing Question:
# ID: 27
# Prompt length: 757 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 2/174
# Extracted answer: C
# Correct answer: C
# Time: 10.14s
# ----------------------------------------
#
# Processing Question:
# ID: 28
# Prompt length: 798 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 3/174
# Extracted answer: A
# Correct answer: A
# Time: 13.46s
# ----------------------------------------
#
# Processing Question:
# ID: 29
# Prompt length: 776 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 4/174
# Extracted answer: C
# Correct answer: B
# Time: 12.82s
# ----------------------------------------
#
# Processing Question:
# ID: 30
# Prompt length: 792 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 5/174
# Extracted answer: C
# Correct answer: C
# Time: 10.97s
# ----------------------------------------
#
# Processing Question:
# ID: 31
# Prompt length: 892 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 6/174
# Extracted answer: A
# Correct answer: D
# Time: 9.28s
# ----------------------------------------
#
# Processing Question:
# ID: 32
# Prompt length: 689 characters
# Raw response: <extra_id_0>. <extra_id_1>: Opciones:
#
# Evaluation:
# Question 7/174
# Extracted answer: C
# Correct answer: A
# Time: 9.26s
# ----------------------------------------
#
# Processing Question:
# ID: 33
# Prompt length: 504 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 8/174
# Extracted answer: A
# Correct answer: C
# Time: 7.33s
# ----------------------------------------
#
# Processing Question:
# ID: 34
# Prompt length: 558 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 9/174
# Extracted answer: A
# Correct answer: B
# Time: 7.32s
# ----------------------------------------
#
# Processing Question:
# ID: 35
# Prompt length: 937 characters
# Raw response: <extra_id_0>genos tumorales. <extra_id_1>
#
# Evaluation:
# Question 10/174
# Extracted answer: D
# Correct answer: D
# Time: 11.60s
# ----------------------------------------
#
# Processing Question:
# ID: 36
# Prompt length: 903 characters
# Raw response: <extra_id_0>genos del donante.
#
# Evaluation:
# Question 11/174
# Extracted answer: A
# Correct answer: D
# Time: 10.82s
# ----------------------------------------
#
# Processing Question:
# ID: 37
# Prompt length: 930 characters
# Raw response: <extra_id_0> la afirmación CORRECTA:
#
# Evaluation:
# Question 12/174
# Extracted answer: A
# Correct answer: A
# Time: 9.49s
# ----------------------------------------
#
# Processing Question:
# ID: 38
# Prompt length: 806 characters
# Raw response: <extra_id_0> a la respuesta correcta
#
# Evaluation:
# Question 13/174
# Extracted answer: A
# Correct answer: A
# Time: 9.38s
# ----------------------------------------
#
# Processing Question:
# ID: 39
# Prompt length: 802 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 14/174
# Extracted answer: C
# Correct answer: C
# Time: 10.58s
# ----------------------------------------
#
# Processing Question:
# ID: 40
# Prompt length: 704 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 15/174
# Extracted answer: A
# Correct answer: B
# Time: 8.57s
# ----------------------------------------
#
# Processing Question:
# ID: 41
# Prompt length: 888 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 16/174
# Extracted answer: A
# Correct answer: C
# Time: 9.28s
# ----------------------------------------
#
# Processing Question:
# ID: 42
# Prompt length: 632 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 17/174
# Extracted answer: A
# Correct answer: D
# Time: 9.41s
# ----------------------------------------
#
# Processing Question:
# ID: 43
# Prompt length: 948 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 18/174
# Extracted answer: A
# Correct answer: A
# Time: 10.28s
# ----------------------------------------
#
# Processing Question:
# ID: 44
# Prompt length: 492 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 19/174
# Extracted answer: A
# Correct answer: D
# Time: 6.91s
# ----------------------------------------
#
# Processing Question:
# ID: 45
# Prompt length: 475 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 20/174
# Extracted answer: A
# Correct answer: D
# Time: 8.33s
# ----------------------------------------
#
# Processing Question:
# ID: 46
# Prompt length: 570 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 21/174
# Extracted answer: A
# Correct answer: B
# Time: 7.39s
# ----------------------------------------
#
# Processing Question:
# ID: 47
# Prompt length: 1197 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 22/174
# Extracted answer: C
# Correct answer: C
# Time: 11.57s
# ----------------------------------------
#
# Processing Question:
# ID: 48
# Prompt length: 690 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 23/174
# Extracted answer: A
# Correct answer: C
# Time: 9.71s
# ----------------------------------------
#
# Processing Question:
# ID: 49
# Prompt length: 1159 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 24/174
# Extracted answer: C
# Correct answer: B
# Time: 11.27s
# ----------------------------------------
#
# Processing Question:
# ID: 50
# Prompt length: 572 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 25/174
# Extracted answer: A
# Correct answer: C
# Time: 7.47s
# ----------------------------------------
#
# Processing Question:
# ID: 51
# Prompt length: 505 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 26/174
# Extracted answer: A
# Correct answer: A
# Time: 12.19s
# ----------------------------------------
#
# Processing Question:
# ID: 52
# Prompt length: 434 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 27/174
# Extracted answer: A
# Correct answer: D
# Time: 8.47s
# ----------------------------------------
#
# Processing Question:
# ID: 53
# Prompt length: 366 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 28/174
# Extracted answer: A
# Correct answer: C
# Time: 6.29s
# ----------------------------------------
#
# Processing Question:
# ID: 54
# Prompt length: 494 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 29/174
# Extracted answer: A
# Correct answer: B
# Time: 8.31s
# ----------------------------------------
#
# Processing Question:
# ID: 55
# Prompt length: 560 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 30/174
# Extracted answer: C
# Correct answer: C
# Time: 7.31s
# ----------------------------------------
#
# Processing Question:
# ID: 56
# Prompt length: 710 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 31/174
# Extracted answer: A
# Correct answer: D
# Time: 9.56s
# ----------------------------------------
#
# Processing Question:
# ID: 57
# Prompt length: 630 characters
# Raw response: <extra_id_0>. <extra_id_1>. Colgajo
#
# Evaluation:
# Question 32/174
# Extracted answer: A
# Correct answer: A
# Time: 8.66s
# ----------------------------------------
#
# Processing Question:
# ID: 58
# Prompt length: 656 characters
# Raw response: <extra_id_0>. <extra_id_1>. Pregunta
#
# Evaluation:
# Question 33/174
# Extracted answer: A
# Correct answer: A
# Time: 8.11s
# ----------------------------------------
#
# Processing Question:
# ID: 59
# Prompt length: 903 characters
# Raw response: <extra_id_0>. <extra_id_1>: A) Realiz
#
# Evaluation:
# Question 34/174
# Extracted answer: A
# Correct answer: A
# Time: 11.41s
# ----------------------------------------
#
# Processing Question:
# ID: 60
# Prompt length: 488 characters
# Raw response: <extra_id_0>. <extra_id_1>. Pregunta
#
# Evaluation:
# Question 35/174
# Extracted answer: A
# Correct answer: A
# Time: 7.78s
# ----------------------------------------
#
# Processing Question:
# ID: 61
# Prompt length: 948 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 36/174
# Extracted answer: C
# Correct answer: A
# Time: 9.37s
# ----------------------------------------
#
# Processing Question:
# ID: 62
# Prompt length: 643 characters
# Raw response: <extra_id_0>. Pregunta médica:
#
# Evaluation:
# Question 37/174
# Extracted answer: A
# Correct answer: D
# Time: 9.37s
# ----------------------------------------
#
# Processing Question:
# ID: 63
# Prompt length: 932 characters
# Raw response: <extra_id_0>a. Respuestas:
#
# Evaluation:
# Question 38/174
# Extracted answer: A
# Correct answer: D
# Time: 11.30s
# ----------------------------------------
#
# Processing Question:
# ID: 64
# Prompt length: 771 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 39/174
# Extracted answer: C
# Correct answer: 0
# Time: 11.51s
# ----------------------------------------
#
# Processing Question:
# ID: 65
# Prompt length: 1247 characters
# Raw response: <extra_id_0> la respuesta correcta.
#
# Evaluation:
# Question 40/174
# Extracted answer: A
# Correct answer: D
# Time: 12.01s
# ----------------------------------------
#
# Processing Question:
# ID: 66
# Prompt length: 828 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 41/174
# Extracted answer: C
# Correct answer: C
# Time: 9.03s
# ----------------------------------------
#
# Processing Question:
# ID: 67
# Prompt length: 1432 characters
# Raw response: <extra_id_0> a la consulta de gine
#
# Evaluation:
# Question 42/174
# Extracted answer: A
# Correct answer: B
# Time: 14.44s
# ----------------------------------------
#
# Processing Question:
# ID: 68
# Prompt length: 671 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 43/174
# Extracted answer: A
# Correct answer: 0
# Time: 9.83s
# ----------------------------------------
#
# Processing Question:
# ID: 69
# Prompt length: 672 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 44/174
# Extracted answer: A
# Correct answer: A
# Time: 8.21s
# ----------------------------------------
#
# Processing Question:
# ID: 70
# Prompt length: 916 characters
# Raw response: <extra_id_0> con antibióticos locales
#
# Evaluation:
# Question 45/174
# Extracted answer: A
# Correct answer: B
# Time: 9.46s
# ----------------------------------------
#
# Processing Question:
# ID: 71
# Prompt length: 1121 characters
# Raw response: <extra_id_0>, indica cesárea
#
# Evaluation:
# Question 46/174
# Extracted answer: A
# Correct answer: B
# Time: 12.40s
# ----------------------------------------
#
# Processing Question:
# ID: 72
# Prompt length: 858 characters
# Raw response: <extra_id_0>: Gestante de 29 semana
#
# Evaluation:
# Question 47/174
# Extracted answer: A
# Correct answer: D
# Time: 11.14s
# ----------------------------------------
#
# Processing Question:
# ID: 73
# Prompt length: 769 characters
# Raw response: <extra_id_0> la afirmación correcta:
#
# Evaluation:
# Question 48/174
# Extracted answer: A
# Correct answer: B
# Time: 9.03s
# ----------------------------------------
#
# Processing Question:
# ID: 74
# Prompt length: 930 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 49/174
# Extracted answer: C
# Correct answer: C
# Time: 9.84s
# ----------------------------------------
#
# Processing Question:
# ID: 75
# Prompt length: 862 characters
# Raw response: <extra_id_0> la opción correcta:
#
# Evaluation:
# Question 50/174
# Extracted answer: A
# Correct answer: B
# Time: 10.68s
# ----------------------------------------
#
# Processing Question:
# ID: 76
# Prompt length: 805 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 51/174
# Extracted answer: C
# Correct answer: A
# Time: 10.53s
# ----------------------------------------
#
# Processing Question:
# ID: 77
# Prompt length: 633 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 52/174
# Extracted answer: A
# Correct answer: D
# Time: 8.30s
# ----------------------------------------
#
# Processing Question:
# ID: 78
# Prompt length: 635 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 53/174
# Extracted answer: A
# Correct answer: C
# Time: 9.74s
# ----------------------------------------
#
# Processing Question:
# ID: 79
# Prompt length: 477 characters
# Raw response: <extra_id_0>. Respuesta: A)
#
# Evaluation:
# Question 54/174
# Extracted answer: A
# Correct answer: B
# Time: 8.70s
# ----------------------------------------
#
# Processing Question:
# ID: 80
# Prompt length: 931 characters
# Raw response: <extra_id_0>. <extra_id_1>: Pregunta
#
# Evaluation:
# Question 55/174
# Extracted answer: A
# Correct answer: A
# Time: 10.15s
# ----------------------------------------
#
# Processing Question:
# ID: 81
# Prompt length: 635 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 56/174
# Extracted answer: A
# Correct answer: C
# Time: 7.90s
# ----------------------------------------
#
# Processing Question:
# ID: 82
# Prompt length: 682 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 57/174
# Extracted answer: A
# Correct answer: C
# Time: 10.18s
# ----------------------------------------
#
# Processing Question:
# ID: 83
# Prompt length: 704 characters
# Raw response: <extra_id_0> la afirmación correcta:
#
# Evaluation:
# Question 58/174
# Extracted answer: A
# Correct answer: B
# Time: 8.58s
# ----------------------------------------
#
# Processing Question:
# ID: 84
# Prompt length: 1367 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 59/174
# Extracted answer: A
# Correct answer: C
# Time: 12.76s
# ----------------------------------------
#
# Processing Question:
# ID: 87
# Prompt length: 637 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 60/174
# Extracted answer: A
# Correct answer: B
# Time: 8.05s
# ----------------------------------------
#
# Processing Question:
# ID: 88
# Prompt length: 538 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 61/174
# Extracted answer: A
# Correct answer: D
# Time: 8.84s
# ----------------------------------------
#
# Processing Question:
# ID: 89
# Prompt length: 1057 characters
# Raw response: <extra_id_0>o. Respuestas:
#
# Evaluation:
# Question 62/174
# Extracted answer: A
# Correct answer: B
# Time: 10.75s
# ----------------------------------------
#
# Processing Question:
# ID: 90
# Prompt length: 846 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 63/174
# Extracted answer: C
# Correct answer: A
# Time: 9.05s
# ----------------------------------------
#
# Processing Question:
# ID: 91
# Prompt length: 786 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 64/174
# Extracted answer: A
# Correct answer: D
# Time: 10.54s
# ----------------------------------------
#
# Processing Question:
# ID: 92
# Prompt length: 566 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 65/174
# Extracted answer: A
# Correct answer: A
# Time: 8.38s
# ----------------------------------------
#
# Processing Question:
# ID: 93
# Prompt length: 754 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 66/174
# Extracted answer: C
# Correct answer: C
# Time: 8.67s
# ----------------------------------------
#
# Processing Question:
# ID: 94
# Prompt length: 991 characters
# Raw response: <extra_id_0>o izquierdo.
#
# Evaluation:
# Question 67/174
# Extracted answer: D
# Correct answer: B
# Time: 11.68s
# ----------------------------------------
#
# Processing Question:
# ID: 95
# Prompt length: 805 characters
# Raw response: <extra_id_0>a. Señale la
#
# Evaluation:
# Question 68/174
# Extracted answer: A
# Correct answer: D
# Time: 10.63s
# ----------------------------------------
#
# Processing Question:
# ID: 96
# Prompt length: 439 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 69/174
# Extracted answer: A
# Correct answer: B
# Time: 7.45s
# ----------------------------------------
#
# Processing Question:
# ID: 97
# Prompt length: 854 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 70/174
# Extracted answer: A
# Correct answer: B
# Time: 9.81s
# ----------------------------------------
#
# Processing Question:
# ID: 98
# Prompt length: 987 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 71/174
# Extracted answer: A
# Correct answer: B
# Time: 11.70s
# ----------------------------------------
#
# Processing Question:
# ID: 99
# Prompt length: 942 characters
# Raw response: <extra_id_0>. Respuesta: Niña
#
# Evaluation:
# Question 72/174
# Extracted answer: A
# Correct answer: A
# Time: 10.99s
# ----------------------------------------
#
# Processing Question:
# ID: 100
# Prompt length: 1015 characters
# Raw response: <extra_id_0>. <extra_id_1>. Señale
#
# Evaluation:
# Question 73/174
# Extracted answer: A
# Correct answer: B
# Time: 9.91s
# ----------------------------------------
#
# Processing Question:
# ID: 101
# Prompt length: 841 characters
# Raw response: <extra_id_0>. <extra_id_1>: A) El
#
# Evaluation:
# Question 74/174
# Extracted answer: A
# Correct answer: A
# Time: 9.85s
# ----------------------------------------
#
# Processing Question:
# ID: 102
# Prompt length: 831 characters
# Raw response: <extra_id_0>. Pregunta médica:
#
# Evaluation:
# Question 75/174
# Extracted answer: A
# Correct answer: D
# Time: 11.22s
# ----------------------------------------
#
# Processing Question:
# ID: 103
# Prompt length: 815 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 76/174
# Extracted answer: A
# Correct answer: B
# Time: 9.78s
# ----------------------------------------
#
# Processing Question:
# ID: 106
# Prompt length: 817 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 77/174
# Extracted answer: A
# Correct answer: C
# Time: 9.10s
# ----------------------------------------
#
# Processing Question:
# ID: 107
# Prompt length: 1044 characters
# Raw response: <extra_id_0>. Respuestas:
#
# Evaluation:
# Question 78/174
# Extracted answer: A
# Correct answer: C
# Time: 11.59s
# ----------------------------------------
#
# Processing Question:
# ID: 108
# Prompt length: 928 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 79/174
# Extracted answer: A
# Correct answer: B
# Time: 11.93s
# ----------------------------------------
#
# Processing Question:
# ID: 109
# Prompt length: 747 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 80/174
# Extracted answer: A
# Correct answer: D
# Time: 9.53s
# ----------------------------------------
#
# Processing Question:
# ID: 112
# Prompt length: 733 characters
# Raw response: <extra_id_0> cual: Opciones:
#
# Evaluation:
# Question 81/174
# Extracted answer: C
# Correct answer: C
# Time: 8.23s
# ----------------------------------------
#
# Processing Question:
# ID: 113
# Prompt length: 731 characters
# Raw response: <extra_id_0> la opción correcta:
#
# Evaluation:
# Question 82/174
# Extracted answer: A
# Correct answer: 0
# Time: 10.12s
# ----------------------------------------
#
# Processing Question:
# ID: 114
# Prompt length: 934 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 83/174
# Extracted answer: C
# Correct answer: D
# Time: 14.22s
# ----------------------------------------
#
# Processing Question:
# ID: 115
# Prompt length: 1163 characters
# Raw response: <extra_id_0> con EI aórtica
#
# Evaluation:
# Question 84/174
# Extracted answer: A
# Correct answer: D
# Time: 15.13s
# ----------------------------------------
#
# Processing Question:
# ID: 116
# Prompt length: 659 characters
# Raw response: <extra_id_0> la opción correcta:
#
# Evaluation:
# Question 85/174
# Extracted answer: A
# Correct answer: A
# Time: 8.55s
# ----------------------------------------
#
# Processing Question:
# ID: 117
# Prompt length: 1451 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 86/174
# Extracted answer: C
# Correct answer: D
# Time: 14.21s
# ----------------------------------------
#
# Processing Question:
# ID: 118
# Prompt length: 596 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 87/174
# Extracted answer: A
# Correct answer: D
# Time: 7.51s
# ----------------------------------------
#
# Processing Question:
# ID: 119
# Prompt length: 618 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 88/174
# Extracted answer: A
# Correct answer: A
# Time: 9.58s
# ----------------------------------------
#
# Processing Question:
# ID: 120
# Prompt length: 737 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 89/174
# Extracted answer: A
# Correct answer: C
# Time: 8.75s
# ----------------------------------------
#
# Processing Question:
# ID: 121
# Prompt length: 1180 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 90/174
# Extracted answer: C
# Correct answer: A
# Time: 10.93s
# ----------------------------------------
#
# Processing Question:
# ID: 122
# Prompt length: 967 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 91/174
# Extracted answer: A
# Correct answer: B
# Time: 10.94s
# ----------------------------------------
#
# Processing Question:
# ID: 123
# Prompt length: 1172 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 92/174
# Extracted answer: C
# Correct answer: D
# Time: 12.65s
# ----------------------------------------
#
# Processing Question:
# ID: 124
# Prompt length: 751 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 93/174
# Extracted answer: A
# Correct answer: D
# Time: 9.95s
# ----------------------------------------
#
# Processing Question:
# ID: 125
# Prompt length: 1045 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 94/174
# Extracted answer: C
# Correct answer: B
# Time: 10.55s
# ----------------------------------------
#
# Processing Question:
# ID: 126
# Prompt length: 501 characters
# Raw response: <extra_id_0>. <extra_id_1>: Pregunta
#
# Evaluation:
# Question 95/174
# Extracted answer: A
# Correct answer: D
# Time: 7.21s
# ----------------------------------------
#
# Processing Question:
# ID: 127
# Prompt length: 930 characters
# Raw response: <extra_id_0>. <extra_id_1>. Selecciona
#
# Evaluation:
# Question 96/174
# Extracted answer: A
# Correct answer: A
# Time: 11.49s
# ----------------------------------------
#
# Processing Question:
# ID: 128
# Prompt length: 1144 characters
# Raw response: <extra_id_0> qué afirmación de las
#
# Evaluation:
# Question 97/174
# Extracted answer: A
# Correct answer: B
# Time: 12.60s
# ----------------------------------------
#
# Processing Question:
# ID: 129
# Prompt length: 427 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 98/174
# Extracted answer: A
# Correct answer: D
# Time: 6.69s
# ----------------------------------------
#
# Processing Question:
# ID: 130
# Prompt length: 744 characters
# Raw response: <extra_id_0>atosis hepática metab
#
# Evaluation:
# Question 99/174
# Extracted answer: B
# Correct answer: C
# Time: 10.09s
# ----------------------------------------
#
# Processing Question:
# ID: 131
# Prompt length: 1116 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 100/174
# Extracted answer: A
# Correct answer: C
# Time: 13.24s
# ----------------------------------------
#
# Processing Question:
# ID: 132
# Prompt length: 961 characters
# Raw response: <extra_id_0>. Respuestas:
#
# Evaluation:
# Question 101/174
# Extracted answer: A
# Correct answer: D
# Time: 11.10s
# ----------------------------------------
#
# Processing Question:
# ID: 133
# Prompt length: 803 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 102/174
# Extracted answer: C
# Correct answer: A
# Time: 9.21s
# ----------------------------------------
#
# Processing Question:
# ID: 134
# Prompt length: 579 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 103/174
# Extracted answer: C
# Correct answer: C
# Time: 8.54s
# ----------------------------------------
#
# Processing Question:
# ID: 135
# Prompt length: 1087 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 104/174
# Extracted answer: C
# Correct answer: A
# Time: 12.34s
# ----------------------------------------
#
# Processing Question:
# ID: 138
# Prompt length: 650 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 105/174
# Extracted answer: A
# Correct answer: C
# Time: 8.51s
# ----------------------------------------
#
# Processing Question:
# ID: 139
# Prompt length: 732 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 106/174
# Extracted answer: C
# Correct answer: A
# Time: 8.37s
# ----------------------------------------
#
# Processing Question:
# ID: 140
# Prompt length: 535 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 107/174
# Extracted answer: A
# Correct answer: C
# Time: 9.28s
# ----------------------------------------
#
# Processing Question:
# ID: 141
# Prompt length: 466 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 108/174
# Extracted answer: A
# Correct answer: B
# Time: 7.16s
# ----------------------------------------
#
# Processing Question:
# ID: 142
# Prompt length: 678 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 109/174
# Extracted answer: C
# Correct answer: C
# Time: 9.23s
# ----------------------------------------
#
# Processing Question:
# ID: 143
# Prompt length: 876 characters
# Raw response: <extra_id_0>. Respuestas:
#
# Evaluation:
# Question 110/174
# Extracted answer: A
# Correct answer: A
# Time: 11.90s
# ----------------------------------------
#
# Processing Question:
# ID: 145
# Prompt length: 1288 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 111/174
# Extracted answer: A
# Correct answer: C
# Time: 14.69s
# ----------------------------------------
#
# Processing Question:
# ID: 146
# Prompt length: 621 characters
# Raw response: <extra_id_0> la opción correcta:
#
# Evaluation:
# Question 112/174
# Extracted answer: A
# Correct answer: C
# Time: 8.38s
# ----------------------------------------
#
# Processing Question:
# ID: 147
# Prompt length: 765 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 113/174
# Extracted answer: C
# Correct answer: C
# Time: 8.75s
# ----------------------------------------
#
# Processing Question:
# ID: 148
# Prompt length: 1272 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 114/174
# Extracted answer: A
# Correct answer: A
# Time: 13.60s
# ----------------------------------------
#
# Processing Question:
# ID: 149
# Prompt length: 694 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 115/174
# Extracted answer: A
# Correct answer: C
# Time: 10.39s
# ----------------------------------------
#
# Processing Question:
# ID: 150
# Prompt length: 624 characters
# Raw response: <extra_id_0> la opción correcta:
#
# Evaluation:
# Question 116/174
# Extracted answer: A
# Correct answer: D
# Time: 8.05s
# ----------------------------------------
#
# Processing Question:
# ID: 151
# Prompt length: 452 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 117/174
# Extracted answer: A
# Correct answer: A
# Time: 6.95s
# ----------------------------------------
#
# Processing Question:
# ID: 152
# Prompt length: 942 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 118/174
# Extracted answer: C
# Correct answer: A
# Time: 11.74s
# ----------------------------------------
#
# Processing Question:
# ID: 153
# Prompt length: 590 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 119/174
# Extracted answer: A
# Correct answer: C
# Time: 7.94s
# ----------------------------------------
#
# Processing Question:
# ID: 154
# Prompt length: 641 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 120/174
# Extracted answer: A
# Correct answer: B
# Time: 8.07s
# ----------------------------------------
#
# Processing Question:
# ID: 155
# Prompt length: 630 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 121/174
# Extracted answer: A
# Correct answer: D
# Time: 9.19s
# ----------------------------------------
#
# Processing Question:
# ID: 156
# Prompt length: 1055 characters
# Raw response: <extra_id_0>o. Respuestas:
#
# Evaluation:
# Question 122/174
# Extracted answer: A
# Correct answer: C
# Time: 10.50s
# ----------------------------------------
#
# Processing Question:
# ID: 157
# Prompt length: 507 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 123/174
# Extracted answer: A
# Correct answer: C
# Time: 7.11s
# ----------------------------------------
#
# Processing Question:
# ID: 158
# Prompt length: 519 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 124/174
# Extracted answer: A
# Correct answer: D
# Time: 8.70s
# ----------------------------------------
#
# Processing Question:
# ID: 159
# Prompt length: 990 characters
# Raw response: <extra_id_0> riesgo de caída
#
# Evaluation:
# Question 125/174
# Extracted answer: A
# Correct answer: D
# Time: 10.61s
# ----------------------------------------
#
# Processing Question:
# ID: 160
# Prompt length: 1182 characters
# Raw response: <extra_id_0>. <extra_id_1> la respuesta correcta
#
# Evaluation:
# Question 126/174
# Extracted answer: A
# Correct answer: B
# Time: 10.53s
# ----------------------------------------
#
# Processing Question:
# ID: 161
# Prompt length: 739 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 127/174
# Extracted answer: A
# Correct answer: B
# Time: 9.58s
# ----------------------------------------
#
# Processing Question:
# ID: 162
# Prompt length: 635 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 128/174
# Extracted answer: C
# Correct answer: B
# Time: 9.31s
# ----------------------------------------
#
# Processing Question:
# ID: 163
# Prompt length: 771 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 129/174
# Extracted answer: C
# Correct answer: B
# Time: 8.72s
# ----------------------------------------
#
# Processing Question:
# ID: 164
# Prompt length: 492 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 130/174
# Extracted answer: C
# Correct answer: B
# Time: 7.81s
# ----------------------------------------
#
# Processing Question:
# ID: 165
# Prompt length: 888 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 131/174
# Extracted answer: A
# Correct answer: A
# Time: 11.21s
# ----------------------------------------
#
# Processing Question:
# ID: 166
# Prompt length: 650 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 132/174
# Extracted answer: A
# Correct answer: C
# Time: 8.43s
# ----------------------------------------
#
# Processing Question:
# ID: 167
# Prompt length: 740 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 133/174
# Extracted answer: A
# Correct answer: A
# Time: 9.00s
# ----------------------------------------
#
# Processing Question:
# ID: 168
# Prompt length: 694 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 134/174
# Extracted answer: A
# Correct answer: B
# Time: 9.94s
# ----------------------------------------
#
# Processing Question:
# ID: 169
# Prompt length: 989 characters
# Raw response: <extra_id_0> la respuesta correcta. <extra_id_1>
#
# Evaluation:
# Question 135/174
# Extracted answer: D
# Correct answer: C
# Time: 10.70s
# ----------------------------------------
#
# Processing Question:
# ID: 170
# Prompt length: 533 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 136/174
# Extracted answer: A
# Correct answer: A
# Time: 7.62s
# ----------------------------------------
#
# Processing Question:
# ID: 171
# Prompt length: 1369 characters
# Raw response: <extra_id_0>. Respuestas: A
#
# Evaluation:
# Question 137/174
# Extracted answer: A
# Correct answer: D
# Time: 14.70s
# ----------------------------------------
#
# Processing Question:
# ID: 172
# Prompt length: 920 characters
# Raw response: <extra_id_0>. Respuesta: Opciones
#
# Evaluation:
# Question 138/174
# Extracted answer: C
# Correct answer: B
# Time: 19.72s
# ----------------------------------------
#
# Processing Question:
# ID: 173
# Prompt length: 510 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 139/174
# Extracted answer: A
# Correct answer: A
# Time: 8.79s
# ----------------------------------------
#
# Processing Question:
# ID: 174
# Prompt length: 1123 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 140/174
# Extracted answer: A
# Correct answer: B
# Time: 13.12s
# ----------------------------------------
#
# Processing Question:
# ID: 175
# Prompt length: 1035 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 141/174
# Extracted answer: C
# Correct answer: A
# Time: 12.93s
# ----------------------------------------
#
# Processing Question:
# ID: 176
# Prompt length: 950 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 142/174
# Extracted answer: C
# Correct answer: C
# Time: 10.60s
# ----------------------------------------
#
# Processing Question:
# ID: 177
# Prompt length: 805 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 143/174
# Extracted answer: C
# Correct answer: C
# Time: 8.75s
# ----------------------------------------
#
# Processing Question:
# ID: 178
# Prompt length: 1085 characters
# Raw response: <extra_id_0> la afirmación correcta:
#
# Evaluation:
# Question 144/174
# Extracted answer: A
# Correct answer: B
# Time: 12.10s
# ----------------------------------------
#
# Processing Question:
# ID: 179
# Prompt length: 1424 characters
# Raw response: <extra_id_0>. <extra_id_1> la respuesta correcta
#
# Evaluation:
# Question 145/174
# Extracted answer: A
# Correct answer: C
# Time: 14.57s
# ----------------------------------------
#
# Processing Question:
# ID: 180
# Prompt length: 1565 characters
# Raw response: <extra_id_0>. <extra_id_1>s: A)
#
# Evaluation:
# Question 146/174
# Extracted answer: A
# Correct answer: 0
# Time: 17.16s
# ----------------------------------------
#
# Processing Question:
# ID: 181
# Prompt length: 988 characters
# Raw response: <extra_id_0>oscopia positiva y
#
# Evaluation:
# Question 147/174
# Extracted answer: A
# Correct answer: B
# Time: 11.08s
# ----------------------------------------
#
# Processing Question:
# ID: 184
# Prompt length: 1026 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 148/174
# Extracted answer: C
# Correct answer: A
# Time: 11.96s
# ----------------------------------------
#
# Processing Question:
# ID: 185
# Prompt length: 1087 characters
# Raw response: <extra_id_0> oxigenoterapia sin respuesta
#
# Evaluation:
# Question 149/174
# Extracted answer: A
# Correct answer: C
# Time: 12.69s
# ----------------------------------------
#
# Processing Question:
# ID: 186
# Prompt length: 938 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 150/174
# Extracted answer: C
# Correct answer: D
# Time: 10.39s
# ----------------------------------------
#
# Processing Question:
# ID: 187
# Prompt length: 1002 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 151/174
# Extracted answer: C
# Correct answer: A
# Time: 10.29s
# ----------------------------------------
#
# Processing Question:
# ID: 188
# Prompt length: 425 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 152/174
# Extracted answer: A
# Correct answer: C
# Time: 7.38s
# ----------------------------------------
#
# Processing Question:
# ID: 189
# Prompt length: 698 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 153/174
# Extracted answer: A
# Correct answer: D
# Time: 8.97s
# ----------------------------------------
#
# Processing Question:
# ID: 190
# Prompt length: 600 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 154/174
# Extracted answer: A
# Correct answer: D
# Time: 7.74s
# ----------------------------------------
#
# Processing Question:
# ID: 191
# Prompt length: 681 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 155/174
# Extracted answer: A
# Correct answer: B
# Time: 10.28s
# ----------------------------------------
#
# Processing Question:
# ID: 192
# Prompt length: 1300 characters
# Raw response: <extra_id_0> la afirmación CORRECTA:
#
# Evaluation:
# Question 156/174
# Extracted answer: A
# Correct answer: B
# Time: 13.65s
# ----------------------------------------
#
# Processing Question:
# ID: 193
# Prompt length: 543 characters
# Raw response: <extra_id_0>. <extra_id_1>. Pregunta
#
# Evaluation:
# Question 157/174
# Extracted answer: A
# Correct answer: C
# Time: 7.54s
# ----------------------------------------
#
# Processing Question:
# ID: 194
# Prompt length: 1022 characters
# Raw response: <extra_id_0>. <extra_id_1>. Respuesta:
#
# Evaluation:
# Question 158/174
# Extracted answer: A
# Correct answer: C
# Time: 11.01s
# ----------------------------------------
#
# Processing Question:
# ID: 195
# Prompt length: 865 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 159/174
# Extracted answer: A
# Correct answer: C
# Time: 10.77s
# ----------------------------------------
#
# Processing Question:
# ID: 196
# Prompt length: 798 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 160/174
# Extracted answer: A
# Correct answer: B
# Time: 10.35s
# ----------------------------------------
#
# Processing Question:
# ID: 197
# Prompt length: 518 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 161/174
# Extracted answer: A
# Correct answer: A
# Time: 7.35s
# ----------------------------------------
#
# Processing Question:
# ID: 198
# Prompt length: 941 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 162/174
# Extracted answer: C
# Correct answer: B
# Time: 11.37s
# ----------------------------------------
#
# Processing Question:
# ID: 199
# Prompt length: 957 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 163/174
# Extracted answer: A
# Correct answer: D
# Time: 11.83s
# ----------------------------------------
#
# Processing Question:
# ID: 200
# Prompt length: 1054 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 164/174
# Extracted answer: C
# Correct answer: A
# Time: 12.17s
# ----------------------------------------
#
# Processing Question:
# ID: 201
# Prompt length: 511 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 165/174
# Extracted answer: A
# Correct answer: B
# Time: 7.46s
# ----------------------------------------
#
# Processing Question:
# ID: 202
# Prompt length: 857 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 166/174
# Extracted answer: C
# Correct answer: D
# Time: 10.46s
# ----------------------------------------
#
# Processing Question:
# ID: 203
# Prompt length: 619 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 167/174
# Extracted answer: A
# Correct answer: B
# Time: 9.89s
# ----------------------------------------
#
# Processing Question:
# ID: 204
# Prompt length: 1439 characters
# Raw response: <extra_id_0>. <extra_id_1>: <extra_id_2>: <extra_id_3>
#
# Evaluation:
# Question 168/174
# Extracted answer: D
# Correct answer: D
# Time: 14.44s
# ----------------------------------------
#
# Processing Question:
# ID: 205
# Prompt length: 938 characters
# Raw response: <extra_id_0>. <extra_id_1>s por semana.
#
# Evaluation:
# Question 169/174
# Extracted answer: A
# Correct answer: D
# Time: 10.06s
# ----------------------------------------
#
# Processing Question:
# ID: 206
# Prompt length: 912 characters
# Raw response: <extra_id_0>. Pregunta médica:
#
# Evaluation:
# Question 170/174
# Extracted answer: A
# Correct answer: 0
# Time: 10.30s
# ----------------------------------------
#
# Processing Question:
# ID: 207
# Prompt length: 1112 characters
# Raw response: <extra_id_0>. Respuestas:
#
# Evaluation:
# Question 171/174
# Extracted answer: A
# Correct answer: A
# Time: 11.98s
# ----------------------------------------
#
# Processing Question:
# ID: 208
# Prompt length: 774 characters
# Raw response: <extra_id_0>. <extra_id_1> la opción correct
#
# Evaluation:
# Question 172/174
# Extracted answer: C
# Correct answer: A
# Time: 10.44s
# ----------------------------------------
#
# Processing Question:
# ID: 209
# Prompt length: 587 characters
# Raw response: <extra_id_0> la opción correcta.
#
# Evaluation:
# Question 173/174
# Extracted answer: A
# Correct answer: B
# Time: 8.31s
# ----------------------------------------
#
# Processing Question:
# ID: 210
# Prompt length: 1166 characters
# Raw response: <extra_id_0>. <extra_id_1>. <extra_id_2>.
#
# Evaluation:
# Question 174/174
# Extracted answer: D
# Correct answer: D
# Time: 11.22s
# ----------------------------------------
#
# Evaluation Summary:
# Model: google/mt5-large
# Total Questions: 174
# Valid Responses: 174
# Invalid Formats: 0
# Correct Answers: 43
# Accuracy (of valid): 24.71%
# Avg Time: 10.18s
